# %% [markdown]
# # Web Scraping Assignment-4

# %%
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

 
from selenium import webdriver


from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException,ElementNotInteractableException


import requests


import re
# Out:
# C:\Users\SHUBHAM\anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %% [markdown]
# Q1.Scrape the details of most viewed videos on YouTube from Wikipedia: Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/ You need to find following details: A) Rank B) Name C) Artist D) Upload date E) Views

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)


url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)

time.sleep(2)

name=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]")
    for i in names:
        name.append(i.text)
except NoSuchElementException:#handling no such element exception
    name.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    name.append('No details available')
    
time.sleep(2)    

rank=[]
try:
    ranks=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]")
    for i in ranks:
        rank.append(i.text)
except NoSuchElementException:#handling no such element exception
    rank.append('No details available')
except StaleElementReferenceException:#handling Stale element exception
    rank.append('No details available')

time.sleep(2)

artist=[]
try:
    artists=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
    for i in artists:
        artist.append(i.text)
except NoSuchElementException:
    artist.append('No details available')
except StaleElementReferenceException:
    artist.append('No details available')
    
time.sleep(2)    

views=[]
try:
    views_list=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
    for i in views_list:
        views.append(i.text)
except NoSuchElementException:
    views.append('No details available')
except StaleElementReferenceException:
    views.append('No details available')
    
time.sleep(2)    

upload_date=[]
try:
    upload_date_list=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
    for i in upload_date_list:
        upload_date.append(i.text)
except NoSuchElementException:
    upload_date.append('No details available')
except StaleElementReferenceException:
    upload_date.append('No details available')
    
time.sleep(2)    

df=pd.DataFrame({"Rank":rank,
                 "Name":name,
                "Uploader/artist":artist,
                "Date of upload":upload_date,
                "Views(in billion)":views})
df
# Out:
# <ipython-input-2-871cf30748f1>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("chromedriver.exe")
# <ipython-input-2-871cf30748f1>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   names=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]")
# <ipython-input-2-871cf30748f1>:24: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ranks=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]")
# <ipython-input-2-871cf30748f1>:36: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   artists=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
# <ipython-input-2-871cf30748f1>:48: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   views_list=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
# <ipython-input-2-871cf30748f1>:60: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   upload_date_list=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
#    Rank                                             Name  \
# 0    1.                           "Baby Shark Dance"[23]
# 1    2.                                  "Despacito"[25]
# 2    3.                       "Johny Johny Yes Papa"[26]
# 3    4.                               "Shape of You"[27]
# 4    5.                              "See You Again"[28]
# 5    6.                                  "Bath Song"[31]
# 6    7.  "Learning Colors – Colorful Eggs on a Farm"[32]
# 7    8.   "Masha and the Bear – Recipe for Disaster"[33]
# 8    9.                                "Uptown Funk"[34]
# 9   10.                "Phonics Song with Two Words"[35]
# 10  11.                              "Gangnam Style"[36]
# 11  12.                             "Dame Tu Cosita"[38]
# 12  13.                                      "Sugar"[39]
# 13  14.                                      "Sorry"[40]
# 14  15.                                       "Roar"[41]
# 15  16.                             "Counting Stars"[42]
# 16  17.                          "Thinking Out Loud"[43]
# 17  18.                          "Wheels on the Bus"[44]
# 18  19.                                      "Faded"[45]
# 19  20.                                 "Dark Horse"[46]
# 20  21.                             "Girls Like You"[47]
# 21  22.                                    "Lean On"[48]
# 22  23.                                   "Bailando"[49]
# 23  24.                               "Shake It Off"[50]
# 24  25.                                 "Let Her Go"[51]
# 25  26.                                     "Axel F"[52]
# 26  27.                                    "Perfect"[53]
# 27  28.                                   "Mi Gente"[54]
# 28  29.           "Waka Waka (This Time for Africa)"[55]
# 29  30.                                      "Hello"[56]
#
#                                 Uploader/artist     Date of upload  \
# 0   Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016
# 1                                    Luis Fonsi   January 12, 2017
# 2                                   LooLoo Kids    October 8, 2016
# 3                                    Ed Sheeran   January 30, 2017
# 4                                   Wiz Khalifa      April 6, 2015
# 5                    Cocomelon – Nursery Rhymes        May 2, 2018
# 6                                   Miroshka TV  February 27, 2018
# 7                                    Get Movies   January 31, 2012
# 8                                   Mark Ronson  November 19, 2014
# 9                                     ChuChu TV      March 6, 2014
# 10                                          Psy      July 15, 2012
# 11                                    El Chombo      April 5, 2018
# 12                                     Maroon 5   January 14, 2015
# 13                                Justin Bieber   October 22, 2015
# 14                                   Katy Perry  September 5, 2013
# 15                                  OneRepublic       May 31, 2013
# 16                                   Ed Sheeran    October 7, 2014
# 17                   Cocomelon – Nursery Rhymes       May 24, 2018
# 18                                  Alan Walker   December 3, 2015
# 19                                   Katy Perry  February 20, 2014
# 20                                     Maroon 5       May 31, 2018
# 21                                  Major Lazer     March 22, 2015
# 22                             Enrique Iglesias     April 11, 2014
# 23                                 Taylor Swift    August 18, 2014
# 24                                    Passenger      July 25, 2012
# 25                                   Crazy Frog      June 16, 2009
# 26                                   Ed Sheeran   November 9, 2017
# 27                                     J Balvin      June 29, 2017
# 28                                      Shakira       June 4, 2010
# 29                                        Adele   October 22, 2015
#
#    Views(in billion)
# 0               9.58
# 1               7.61
# 2               5.85
# 3               5.51
# 4               5.31
# 5               4.60
# 6               4.53
# 7               4.47
# 8               4.34
# 9               4.27
# 10              4.24
# 11              3.67
# 12              3.58
# 13              3.48
# 14              3.46
# 15              3.43
# 16              3.35
# 17              3.33
# 18              3.17
# 19              3.17
# 20              3.16
# 21              3.12
# 22              3.12
# 23              3.11
# 24              3.11
# 25              3.08
# 26              3.00
# 27              3.00
# 28              2.98
# 29              2.90

# %% [markdown]
# Q2.Scrape the details team India’s international fixtures from bcci.tv. Url = https://www.bcci.tv/. You need to find following details: A) Match title (I.e. 1 st ODI) B) Series C) Place D) Date E) Time Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
driver=webdriver.Chrome("chromedriver.exe") 


time.sleep(2)

url = "https://www.bcci.tv/"
driver.get(url)

time.sleep(2)

fixtures=driver.find_element_by_xpath("//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']/div/ul/li/a")
try:
    fixtures.click()
except ElementNotInteractableException:
    driver.get(fixtures.get_attribute('href'))
    

time.sleep(2)

urls=[]
match_page=driver.find_elements_by_xpath("//div[@class='js-list']/a")  
for i in match_page:
    urls.append(i.get_attribute('href'))
  
    
time.sleep(1)   

match=[] 
series=[]
place=[]
date=[]
Time=[]
all_text = []
venue = []


for i in urls:                 
    
    time.sleep(2)
    
    try:                    
        match_title=driver.find_element_by_xpath("//p[@class='mc-header-info__match-description']/span")
        match.append(match_title.text)
    except NoSuchElementException:
        match.append('No details available')
    
    time.sleep(2)
    
    try:
        series_title=driver.find_element_by_xpath("//h1[@class='mc-header-info__title']/strong")
        series.append(series_title.text)
    except NoSuchElementException:
        series.append("No details Available")
    
    time.sleep(2)
    
    try:
        date_title=driver.find_element_by_xpath("//div[@class='mc-header-scorebox__datetime']/strong")
        date.append(date_title.text)
    except NoSuchElementException:
        date.append("No details Available")      
    
    time.sleep(2)
       
    try:
        time_title=driver.find_element_by_xpath("//div[@class='mc-header-scorebox__datetime']/span")
        Time.append(time_title.text)
    except NoSuchElementException:
        Time.append("No details Available")    
      
    time.sleep(2)
      
    try:
        place_title=driver.find_element_by_xpath("//h1[@class='mc-header-info__title']")
        venue.append(place_title.text)
    except NoSuchElementException:
        place.append("No details Available")
        
    
    

for i in venue:
    all_text.append(i.split())
for i in all_text:
    place.append(i[-1::]) 
    
time.sleep(2)       

df=pd.DataFrame({"Match":match,
                "Series":series,
                "Place":place,
                "Date":date,
                "Time":Time})
df
# Out:
# <ipython-input-3-2dcf75ff9adf>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("chromedriver.exe")
# <ipython-input-3-2dcf75ff9adf>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   fixtures=driver.find_element_by_xpath("//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']/div/ul/li/a")
# <ipython-input-3-2dcf75ff9adf>:21: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   match_page=driver.find_elements_by_xpath("//div[@class='js-list']/a")
# <ipython-input-3-2dcf75ff9adf>:43: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   match_title=driver.find_element_by_xpath("//p[@class='mc-header-info__match-description']/span")
# <ipython-input-3-2dcf75ff9adf>:51: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   series_title=driver.find_element_by_xpath("//h1[@class='mc-header-info__title']/strong")
# <ipython-input-3-2dcf75ff9adf>:59: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   date_title=driver.find_element_by_xpath("//div[@class='mc-header-scorebox__datetime']/strong")
# <ipython-input-3-2dcf75ff9adf>:67: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   time_title=driver.find_element_by_xpath("//div[@class='mc-header-scorebox__datetime']/span")
# <ipython-input-3-2dcf75ff9adf>:75: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   place_title=driver.find_element_by_xpath("//h1[@class='mc-header-info__title']")
#       Match               Series        Place                   Date  \
# 0  MATCH 42      India v Namibia      [Dubai]      Monday 8 November
# 1  1ST T20I  India v New Zealand     [Jaipur]  Wednesday 17 November
# 2  2ND T20I  India v New Zealand     [Ranchi]     Friday 19 November
# 3  3RD T20I  India v New Zealand    [Kolkata]     Sunday 21 November
# 4  1ST TEST  India v New Zealand     [Kanpur]   Thursday 25 November
# 5  2ND TEST  India v New Zealand     [Mumbai]      Friday 3 December
# 6   1ST ODI  India v West Indies  [Ahmedabad]      Sunday 6 February
# 7   2ND ODI  India v West Indies     [Jaipur]   Wednesday 9 February
# 8   3RD ODI  India v West Indies    [Kolkata]   Saturday 12 February
# 9  1ST T20I  India v West Indies    [Cuttack]    Tuesday 15 February
#
#         Time
# 0  19:30 IST
# 1  19:00 IST
# 2  19:00 IST
# 3  19:00 IST
# 4  09:30 IST
# 5  09:30 IST
# 6  13:00 IST
# 7  13:00 IST
# 8  13:00 IST
# 9  19:00 IST

# %% [markdown]
# Q3 - Scrape the details of selenium exception from guru99.com. Url = https://www.guru99.com/ You need to find following details: A) Name B) Description Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
url = "https://www.guru99.com/"
page = requests.get(url)
print("Legality Response number from our URL is:", page) # to show the response output from the webpage
soup = BeautifulSoup(page.content)

driver = webdriver.Chrome('chromedriver.exe')
driver.get(url)
driver.maximize_window()

error = driver.find_element_by_xpath('//*[@id="java_technologies"]/li[3]/a').get_attribute('href')
driver.get(error)
time.sleep(3)
exception = driver.find_element_by_xpath('/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a').get_attribute('href')
driver.get(exception)

Data = []
table = driver.find_elements_by_xpath("//table[@class='table table-striped']//td")
for i in table:
    try:
        Data.append(i.text)
    except NoSuchElementException:
        Data.append('-')

Name = []
for i in range(2,len(Data),2):
    Name.append(Data[i])

Description = []
for i in range(3,len(Data),2):
    Description.append(Data[i])

df=pd.DataFrame({"Exception name": Name, "Exception description": Description})
df
# Out:
# Legality Response number from our URL is: <Response [200]>
# <ipython-input-4-621750962fcf>:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')
# <ipython-input-4-621750962fcf>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   error = driver.find_element_by_xpath('//*[@id="java_technologies"]/li[3]/a').get_attribute('href')
# <ipython-input-4-621750962fcf>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   exception = driver.find_element_by_xpath('/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a').get_attribute('href')
# <ipython-input-4-621750962fcf>:17: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   table = driver.find_elements_by_xpath("//table[@class='table table-striped']//td")
#                          Exception name  \
# 0         ElementNotSelectableException
# 1                NoSuchElementException
# 2                  NoSuchFrameException
# 3               NoAlertPresentException
# 4                 NoSuchWindowException
# 5        StaleElementReferenceException
# 6              SessionNotFoundException
# 7                      TimeoutException
# 8                    WebDriverException
# 9             ConnectionClosedException
# 10     ElementClickInterceptedException
# 11      ElementNotInteractableException
# 12             ErrorInResponseException
# 13  ErrorHandler.UnknownServerException
# 14         ImeActivationFailedException
# 15             ImeNotAvailableException
# 16         InsecureCertificateException
# 17             InvalidArgumentException
# 18         InvalidCookieDomainException
# 19          InvalidCoordinatesException
# 20          InvalidElementStateExceptio
# 21            InvalidSessionIdException
# 22       InvalidSwitchToTargetException
# 23                  JavascriptException
# 24                        JsonException
# 25             NoSuchAttributeException
# 26       MoveTargetOutOfBoundsException
# 27               NoSuchContextException
# 28                NoSuchCookieException
# 29                    NotFoundException
# 30          RemoteDriverServerException
# 31                  ScreenshotException
# 32           SessionNotCreatedException
# 33           UnableToSetCookieException
# 34           UnexpectedTagNameException
# 35              UnhandledAlertException
# 36      UnexpectedAlertPresentException
# 37               UnknownMethodException
# 38          UnreachableBrowserException
# 39          UnsupportedCommandException
#
#                                 Exception description
# 0   This Selenium exception occurs when an element...
# 1   This Exception occurs if an element could not ...
# 2   This Exception occurs if the frame target to b...
# 3   This Exception occurs when you switch to no pr...
# 4   This Exception occurs if the window target to ...
# 5   This Selenium exception occurs happens when th...
# 6   The WebDriver is acting after you quit the bro...
# 7   Thrown when there is not enough time for a com...
# 8   This Exception takes place when the WebDriver ...
# 9   This type of Exception takes place when there ...
# 10  The command may not be completed as the elemen...
# 11  This Selenium exception is thrown when any ele...
# 12  This happens while interacting with the Firefo...
# 13  Exception is used as a placeholder in case if ...
# 14  This expectation will occur when IME engine ac...
# 15    It takes place when IME support is unavailable.
# 16  Navigation made the user agent to hit a certif...
# 17  It occurs when an argument does not belong to ...
# 18  This happens when you try to add a cookie unde...
# 19  This type of Exception matches an interacting ...
# 20  It occurs when command can’t be finished when ...
# 21  This Exception took place when the given sessi...
# 22  This occurs when the frame or window target to...
# 23  This issue occurs while executing JavaScript g...
# 24  It occurs when you afford to get the session w...
# 25  This kind of Exception occurs when the attribu...
# 26  It takes place if the target provided to the A...
# 27           ContextAware does mobile device testing.
# 28  This Exception occurs when no cookie matching ...
# 29  This Exception is a subclass of WebDriverExcep...
# 30  This Selenium exception is thrown when the ser...
# 31            It is not possible to capture a screen.
# 32  It happens when a new session could not be suc...
# 33  This occurs if a driver is unable to set a coo...
# 34  Happens if a support class did not get a web e...
# 35  This expectation occurs when there is an alert...
# 36  It occurs when there is the appearance of an u...
# 37  This Exception happens when the requested comm...
# 38  This Exception occurs only when the browser is...
# 39  This occurs when remote WebDriver does n’t sen...

# %% [markdown]
# Q4. Scrape the details of State-wise GDP of India from statisticstime.com. Url = http://statisticstimes.com/ You have to find following details: A) Rank B) State C) GSDP(19-20) D) GSDP(18-19) E) Share(18-19) F) GDP($ billion) Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)

url = "http://statisticstimes.com/"
driver.get(url)
time.sleep(2)

economy=driver.find_element_by_xpath("//div[@class='dropdown'][2]/div/a[3]")
try:
    economy.click()
except ElementNotInteractableException:
    driver.get(economy.get_attribute('href'))
time.sleep(2)


indian_states=driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']//li[1]/a")

try:
    indian_states.click()
except ElementNotInteractableException:
    driver.get(indian_states.get_attribute('href')) 
time.sleep(2)


rank=[]
try:
    ranks=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[1]")
    for i in ranks:
        rank.append(i.text)
except NoSuchElementException:                 #handling no such element exception
    rank.append('No details available')
time.sleep(2)



State=[]
try:
    states=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[2]")
    for i in states:
        State.append(i.text)
except NoSuchElementException:                 #handling no such element exception
    State.append('No details available')
time.sleep(2)

GSDP_20=[]
try:
    info=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[3]")
    for i in info:
        GSDP_20.append(i.text)
except NoSuchElementException:           #handling no such element exception
    GSDP_20.append('No details available')
time.sleep(2)    
    
GSDP_19=[]
try:
    info=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[4]")
    for i in info:
        GSDP_19.append(i.text)
except NoSuchElementException:        #handling no such element exception
    GSDP_19.append('No details available')
time.sleep(2)


share=[]
try:
    info=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[5]")
    for i in info:
        share.append(i.text)
except NoSuchElementException:          #handling no such element exception
    share.append('No details available')
time.sleep(2)


GDP_billion=[]
try:
    info=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[6]")
    for i in info:
        GDP_billion.append(i.text)
except NoSuchElementException:            #handling no such element exception
    GDP_billion.append('No details available')
time.sleep(2)


df=pd.DataFrame({'Rank':rank,
                'State':State,
                'GSDP(19-20)':GSDP_20,
                'GSDP(18-19)':GSDP_19,
                'Share(18-19)':share,
                'GDP(Billion_$)':GDP_billion})
df
# Out:
# <ipython-input-5-665781e141d2>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("chromedriver.exe")
# <ipython-input-5-665781e141d2>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   economy=driver.find_element_by_xpath("//div[@class='dropdown'][2]/div/a[3]")
# <ipython-input-5-665781e141d2>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   indian_states=driver.find_element_by_xpath("//ul[@style='list-style-type:none;margin-left:20px;']//li[1]/a")
# <ipython-input-5-665781e141d2>:27: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ranks=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[1]")
# <ipython-input-5-665781e141d2>:38: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   states=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[2]")
# <ipython-input-5-665781e141d2>:47: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   info=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[3]")
# <ipython-input-5-665781e141d2>:56: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   info=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[4]")
# <ipython-input-5-665781e141d2>:66: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   info=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[5]")
# <ipython-input-5-665781e141d2>:76: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   info=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[6]")
#    Rank                      State GSDP(19-20) GSDP(18-19) Share(18-19)  \
# 0     1                Maharashtra           -   2,632,792       13.94%
# 1     2                 Tamil Nadu   1,845,853   1,630,208        8.63%
# 2     3              Uttar Pradesh   1,687,818   1,584,764        8.39%
# 3     4                    Gujarat           -   1,502,899        7.96%
# 4     5                  Karnataka   1,631,977   1,493,127        7.91%
# 5     6                West Bengal   1,253,832   1,089,898        5.77%
# 6     7                  Rajasthan   1,020,989     942,586        4.99%
# 7     8             Andhra Pradesh     972,782     862,957        4.57%
# 8     9                  Telangana     969,604     861,031        4.56%
# 9    10             Madhya Pradesh     906,672     809,592        4.29%
# 10   11                     Kerala           -     781,653        4.14%
# 11   12                      Delhi     856,112     774,870        4.10%
# 12   13                    Haryana     831,610     734,163        3.89%
# 13   14                      Bihar     611,804     530,363        2.81%
# 14   15                     Punjab     574,760     526,376        2.79%
# 15   16                     Odisha     521,275     487,805        2.58%
# 16   17                      Assam           -     315,881        1.67%
# 17   18               Chhattisgarh     329,180     304,063        1.61%
# 18   19                  Jharkhand     328,598     297,204        1.57%
# 19   20                Uttarakhand           -     245,895        1.30%
# 20   21            Jammu & Kashmir           -     155,956        0.83%
# 21   22           Himachal Pradesh     165,472     153,845        0.81%
# 22   23                        Goa      80,449      73,170        0.39%
# 23   24                    Tripura      55,984      49,845        0.26%
# 24   25                 Chandigarh           -      42,114        0.22%
# 25   26                 Puducherry      38,253      34,433        0.18%
# 26   27                  Meghalaya      36,572      33,481        0.18%
# 27   28                     Sikkim      32,496      28,723        0.15%
# 28   29                    Manipur      31,790      27,870        0.15%
# 29   30                   Nagaland           -      27,283        0.14%
# 30   31          Arunachal Pradesh           -      24,603        0.13%
# 31   32                    Mizoram      26,503      22,287        0.12%
# 32   33  Andaman & Nicobar Islands           -           -            -
#
#    GDP(Billion_$)
# 0         399.921
# 1         247.629
# 2         240.726
# 3         228.290
# 4         226.806
# 5         165.556
# 6         143.179
# 7         131.083
# 8         130.791
# 9         122.977
# 10        118.733
# 11        117.703
# 12        111.519
# 13         80.562
# 14         79.957
# 15         74.098
# 16         47.982
# 17         46.187
# 18         45.145
# 19         37.351
# 20         23.690
# 21         23.369
# 22         11.115
# 23          7.571
# 24          6.397
# 25          5.230
# 26          5.086
# 27          4.363
# 28          4.233
# 29          4.144
# 30          3.737
# 31          3.385
# 32              -

# %% [markdown]
# Q5.Scrape the details of trending repositories on Github.com. Url = https://github.com/ You have to find the following details: A) Repository title B) Repository description C) Contributors count D) Language used

# %% [markdown]
# Q6. Scrape the details of top 100 songs on billboard.com. Url = https://www.billboard.com/ You have to find the following details: A) Song name B) Artist name C) Last week rank D) Peak rank E) Weeks on board Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)


url = "https://www.billboard.com/"
driver.get(url)
time.sleep(2)



charts=driver.find_element_by_xpath("//ul[@class='header__subnav__list display--flex flex--left-center flex-md--center-center']//li[3]//a")
try:
    charts.click()
except ElementNotInteractableException:
    driver.get(charts.get_attribute('href'))
time.sleep(2)



song_name=[]
try:
    names=driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")
    for i in names:
        song_name.append(i.text)
except NoSuchElementException:       
    song_name.append('No details available')
time.sleep(2)    



artist_name=[]
try:
    names=driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
    for i in names:
        artist_name.append(i.text)
except NoSuchElementException:        
    artist_name.append('No details available')
time.sleep(2)
    


last_week_rank=[]
try:
    ranks=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
    for i in ranks:
        last_week_rank.append(i.text)
except NoSuchElementException:       
    last_week_rank.append('No details available') 
time.sleep(2)


peak_rank=[]
try:
    ranks=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
    for i in ranks:
        peak_rank.append(i.text)
except NoSuchElementException:      
    peak_rank.append('No details available')
time.sleep(2)


weeks=[]
try:
    week_count=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
    for i in week_count:
        weeks.append(i.text)
except NoSuchElementException:          
    weeks.append('No details available')
time.sleep(2)



df=pd.DataFrame({'Song_Name':song_name,
                'Artist_Name':artist_name,
                'Last_week_rank':last_week_rank,
                'Peak':peak_rank,
                'Weeks_on_chart':weeks})
df
# Out:
# <ipython-input-6-ad0ff2c8c0fb>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("chromedriver.exe")
# <ipython-input-6-ad0ff2c8c0fb>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   charts=driver.find_element_by_xpath("//ul[@class='header__subnav__list display--flex flex--left-center flex-md--center-center']//li[3]//a")
# <ipython-input-6-ad0ff2c8c0fb>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   names=driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")
# <ipython-input-6-ad0ff2c8c0fb>:33: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   names=driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
# <ipython-input-6-ad0ff2c8c0fb>:44: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ranks=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
# <ipython-input-6-ad0ff2c8c0fb>:54: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ranks=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
# <ipython-input-6-ad0ff2c8c0fb>:64: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   week_count=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
#                              Song_Name                 Artist_Name  \
# 0                  Certified Lover Boy                       Drake
# 1          Dangerous: The Double Album               Morgan Wallen
# 2                           Planet Her                    Doja Cat
# 3                  Sincerely, Kentrell  YoungBoy Never Broke Again
# 4                                 Sour              Olivia Rodrigo
# ..                                 ...                         ...
# 195                      High Off Life                      Future
# 196  My Beautiful Dark Twisted Fantasy                  Kanye West
# 197                    To Hell With It              PinkPantheress
# 198                           Cry Baby            Melanie Martinez
# 199                        Born Sinner                     J. Cole
#
#     Last_week_rank Peak Weeks_on_chart
# 0                2    1              8
# 1                8    1             42
# 2                7    2             18
# 3                6    1              5
# 4                9    1             23
# ..             ...  ...            ...
# 195            197    1             76
# 196            199    1            157
# 197             73   73              2
# 198              -    6            136
# 199            191    1            117
#
# [200 rows x 5 columns]

# %% [markdown]
# Q7. Scrape the details of Data science recruiters from naukri.com. Url = https://www.naukri.com/ You have to find the following details: A) Name B) Designation C) Company D) Skills they hire for E) Location

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)


url = "https://www.naukri.com/"
driver.get(url)
time.sleep(2)


recruiters=driver.find_element_by_xpath("//a[@title='Search Recruiters']")
driver.get(recruiters.get_attribute('href'))
time.sleep(1)


search=driver.find_element_by_xpath("//input[@class='sugInp']")
search.send_keys("Data Science")
time.sleep(1)


button=driver.find_element_by_xpath("//button[@id='qsbFormBtn']")
button.click()
time.sleep(1)


name=[]
try:
    names=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/a[1]")
    for i in names:
        name.append(i.text)
except NoSuchElementException:           
    name.append('No details available')
time.sleep(2)



designation=[]
try:
    designation_list=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/span[1]")
    for i in designation_list:
        designation.append(i.text)
except NoSuchElementException:        
    designation.append('No details available')
time.sleep(2)



company=[]
try:
    companies=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/a[2]")
    for i in companies:
        company.append(i.text)
except NoSuchElementException:
    company.append('No details available')
time.sleep(2)


location=[]
soup=BeautifulSoup(driver.page_source,'html.parser')
l=soup.find_all('div',attrs={'vcard'})
for i in l:
    try:
        location.append(i.find('small').text)
    except AttributeError :
        location.append("No details available")
time.sleep(2)


skill=[]
try:
    skills=driver.find_elements_by_xpath("//div[@class='recInfo']/div[2]")
    for i in skills:
        skill.append(i.text)
except NoSuchElementException:        
    skill.append('No details available')
time.sleep(2)    
        

df=pd.DataFrame({'Name':name,
                'Designation':designation,
                'Company':company,
                "Location":location,
                'Skills I hire':skill})
df
# Out:
# <ipython-input-7-954c8074fe07>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("chromedriver.exe")
# <ipython-input-7-954c8074fe07>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   recruiters=driver.find_element_by_xpath("//a[@title='Search Recruiters']")
# <ipython-input-7-954c8074fe07>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search=driver.find_element_by_xpath("//input[@class='sugInp']")
# <ipython-input-7-954c8074fe07>:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_xpath("//button[@id='qsbFormBtn']")
# <ipython-input-7-954c8074fe07>:27: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   names=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/a[1]")
# <ipython-input-7-954c8074fe07>:38: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   designation_list=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/span[1]")
# <ipython-input-7-954c8074fe07>:49: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   companies=driver.find_elements_by_xpath("//div[@class='recInfo']/div/p/a[2]")
# <ipython-input-7-954c8074fe07>:70: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   skills=driver.find_elements_by_xpath("//div[@class='recInfo']/div[2]")
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                       Narasimha
# 8                                     Balu Ramesh
# 9                                   Asif Lucknowi
# 10                                InstaFinancials
# 11                                 Priyanka Akiri
# 12                                Kalpana Dumpala
# 13                                        Mubarak
# 14                                 Kushal Rastogi
# 15                                    Ruchi Dhote
# 16                                   Kapil Devang
# 17                             Mahesh Babu Channa
# 18                             Sandhya Khandagale
# 19                                  Manisha Yadav
# 20                                    Riya Rajesh
# 21                           Rashmi Bhattacharjee
# 22                                  Faizan Kareem
# 23                                 Rithika dadwal
# 24                                      Shaun Rao
# 25                                  Azahar Shaikh
# 26                                          Manas
# 27                                          kumar
# 28                                   Sunil Vedula
# 29                                    Rajat Kumar
# 30                                      Jayanth N
# 31                                    Priya Khare
# 32                                Dhruv Dev Dubey
# 33                                       SREEDHAR
# 34                                     Ravi Dubey
# 35                              Radha Manivasagam
# 36                                  Prateek Kumar
# 37                                    Amit Sharma
# 38                                          Kanan
# 39                           Shashikant Chaudhary
# 40                                           Brad
# 41                                   Rutuja Pawar
# 42                            Madhusudhan Sridhar
# 43                                    Ankit Sinha
# 44                                 Gaurav Chouhan
# 45                                   Rashi Kacker
# 46                                        Ashwini
# 47                                   Balaji Kolli
# 48                                 Rajani Nagaraj
# 49                                    ROHIT Kumar
#
#                             Designation  \
# 0                            HR Manager
# 1                     Company Recruiter
# 2                            Company HR
# 3                     Company Recruiter
# 4                           Founder CEO
# 5           Recruitment Lead Consultant
# 6                     Programme Manager
# 7                     Company Recruiter
# 8                      HR Administrator
# 9                              Director
# 10                       Human Resource
# 11                           HR Manager
# 12                     Executive Hiring
# 13                           Company HR
# 14                           Company HR
# 15  Senior Executive Talent Acquisition
# 16                           HR Manager
# 17                         HR Team Lead
# 18                         HR Recruiter
# 19                         HR Executive
# 20           Manager Talent Acquisition
# 21                              HR Head
# 22                           HR MANAGER
# 23                         HR Recruiter
# 24              Manager Human Resources
# 25                    Company Recruiter
# 26              Lead Talent acquisition
# 27                           Proprietor
# 28                                  CEO
# 29                          Founder CEO
# 30                      Project Manager
# 31                       Senior Manager
# 32             Company Recruitment Head
# 33               Recruitment Consultant
# 34                  Recruitment Manager
# 35                         HR Executive
# 36                                 Head
# 37                           Consultant
# 38         senior technology instructor
# 39             HR Recruiter/HR Excutive
# 40        Manager, Technical Recruiting
# 41                  Technical Recruiter
# 42                      Erp Implementer
# 43                       Head Analytics
# 44              Chief Technical Officer
# 45                   Sr Product Manager
# 46             Director Global Delivery
# 47                           Co Founder
# 48                           HR Manager
# 49                            Architect
#
#                                            Company                  Location  \
# 0                             Data Science Network                     Delhi
# 1                    Shore Infotech India Pvt. Ltd  Hyderabad / Secunderabad
# 2                         MARSIAN Technologies LLP                      Pune
# 3            Enerlytics Software Solutions Pvt Ltd                 Ahmedabad
# 4                                  LibraryXProject             UK - (london)
# 5       Apidel Technologies Division of Transpower         Vadodara / Baroda
# 6                                             IFMR                   Chennai
# 7                        Step Next Private Limited  Hyderabad / Secunderabad
# 8                      Techvantage Systems Pvt Ltd                Trivandrum
# 9                       Weupskill- Live Wire India                    Indore
# 10                CBL Data Science Private Limited     Bengaluru / Bangalore
# 11                   Infinitive Software Solutions                 Hyderabad
# 12                              Innominds Software  Hyderabad / Secunderabad
# 13                                        MoneyTap     Bengaluru / Bangalore
# 14              QuantMagnum Technologies Pvt. Ltd.                    Mumbai
# 15                           Bristlecone India Ltd                      Pune
# 16                                  BISP Solutions                    Bhopal
# 17                               SocialPrachar.com  Hyderabad / Secunderabad
# 18                 Compumatrice Multimedia Pvt Ltd                      Pune
# 19                                        Easi Tax               Navi Mumbai
# 20                     Novelworx Digital Solutions                    Cochin
# 21         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...                     Delhi
# 22                   FirstTech Consaltants Pvt.Ltd  Hyderabad / Secunderabad
# 23                                Affine Analytics                      Pune
# 24                              Exela Technologies                      Pune
# 25                 NEAL ANALYTICS SERVICES PVT LTD                      Pune
# 26      Autumn Leaf Consulting Services Private...     Bengaluru / Bangalore
# 27                                         trainin     Bengaluru / Bangalore
# 28                            Nanoprecise Sci Corp      No details available
# 29                  R.S Consultancy &amp; Services                     Delhi
# 30        Dollarbird Information Services Pvt, Ltd           Mysoru / Mysore
# 31                          Independent Consultant     Bengaluru / Bangalore
# 32                                    Confidential     Bengaluru / Bangalore
# 33     JOBSMILL BUSINESS SOLUTIONS PRIVATE LIMITED  Hyderabad / Secunderabad
# 34                     HyrEzy Talent Solutions LLP                 Ghaziabad
# 35                                      Techcovery     Bengaluru / Bangalore
# 36                                         Trisect                     Noida
# 37                                 ASCO consulting                 New Delhi
# 38                                         NY INST                   Chennai
# 39  3D India Staffing Research &amp; Consulting...                   Aligarh
# 40                                     O.C. Tanner            Salt Lake City
# 41                                   Demand Matrix                      Pune
# 42                             MADHUSUDHAN SRIDHAR     Bengaluru / Bangalore
# 43                                  Suntech Global                    Mumbai
# 44                        Strategic Consulting Lab                    Indore
# 45                            Impel Labs Pvt. Ltd.     Bengaluru / Bangalore
# 46                                    MRP Advisers                    MYSORE
# 47                   Saras Solutions India Pvt Ltd  Hyderabad / Secunderabad
# 48                                     WildJasmine     Bengaluru / Bangalore
# 49                             LNT Private Limited                    Mumbai
#
#                                         Skills I hire
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5   Analytics, Business Intelligence, Business Ana...
# 6                                        Data Science
# 7   Data Modeling, Data Wrangling, seaborn, eda, p...
# 8   Machine Learning, algorithms, Go Getter, Compu...
# 9   Technical Training, Software Development, Pres...
# 10  Software Development, It Sales, Account Manage...
# 11  Oracle Dba, Data Science, Data Warehousing, ET...
# 12  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 13  Business Intelligence, Data Warehousing, Data ...
# 14  Office Administration, Hr Administration, tele...
# 15  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 16     Big Data, Hadoop, Data Analytics, Data Science
# 17  Social Media, digital media maketing, seo, smm...
# 18  Big Data, Data Science, Artificial Intelligenc...
# 19  Telecalling, Client Interaction, Marketing, Re...
# 20                                       Data Science
# 21  Corporate Sales, Software Development, Softwar...
# 22  Data Analytics, Data Science, Machine Learning...
# 23  Data Science, Machine Learning, Python, R, Dee...
# 24  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 25  Data Science, Artificial Intelligence, Machine...
# 26  Software Architecture, Vp Engineering, Product...
# 27  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 28  Signal Processing, Machine Learning, Neural Ne...
# 29  Web Technologies, Project Management, Software...
# 30  Data Analytics, Managed Services, Team Leading...
# 31  Data Science, Artificial Intelligence, analyti...
# 32  Server Administartion, Verilog, Vhdl, Digital ...
# 33  Data Science, Machine Learning, Big Data Analy...
# 34  Walmart Interra Skeps Expressstores indifi whi...
# 35  Python, Artificial Intelligence, Machine Learn...
# 36  Java, Python, Angularjs, Software Testing, Mac...
# 37  Machine Learning, Artificial Intelligence, Dat...
# 38  C, C++, Artificial Intelligence, Python, Php, ...
# 39  Relationship Management, Retail Sales, Private...
# 40                 Data Science, Software Engineering
# 41  Data Science, Big Data Analytics, Digital Mark...
# 42                  Data Science, Recruitment, Salary
# 43  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 44  Software Development, Business Intelligence, B...
# 45                   Data Science, Node.js, Angularjs
# 46  Data Science, Media Marketing, Resource Planni...
# 47  Data Analysis, Learning, Data Science, Compute...
# 48  Java, Hadoop, R, Machine Learning, Spark, Flum...
# 49  Software Development, Core Java, Unit Testing,...

# %% [markdown]
# Q8. Scrape the details of Highest selling novels. Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/ You have to find the following details: A) Book name B) Author name C) Volumes sold D) Publisher E) Genre

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)


url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare"
driver.get(url)
time.sleep(2)


book_name=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[2]")
    for i in names:
        book_name.append(i.text)
except NoSuchElementException:              #handling no such element exception
    book_name.append('No details available')
time.sleep(2)


author_name=[]
try:
    names=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[3]")
    for i in names:
        author_name.append(i.text)
except NoSuchElementException:#handling no such element exception
    author_name.append('No details available')
time.sleep(2)



Sale=[]
try:
    sale=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[4]")
    for i in sale:
        Sale.append(i.text)
except NoSuchElementException:
    Sale.append('No details available')
time.sleep(2)    


publisher=[]
try:
    publishers=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[5]")
    for i in publishers:
        publisher.append(i.text)
except NoSuchElementException:
    publisher.append('No details available')
time.sleep(2)


genre=[]
try:
    genres=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[6]")
    for i in genres:
        genre.append(i.text)
except NoSuchElementException:
    genre.append('No details available')
time.sleep(2)


df=pd.DataFrame({"Book_name":book_name,
                "Author_name":author_name,
                'Volume sold':Sale,
                'Publisher':publisher,
                'Genre':genre})
df
# Out:
# <ipython-input-8-360a4e56e16b>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("chromedriver.exe")
# <ipython-input-8-360a4e56e16b>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   names=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[2]")
# <ipython-input-8-360a4e56e16b>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   names=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[3]")
# <ipython-input-8-360a4e56e16b>:33: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   sale=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[4]")
# <ipython-input-8-360a4e56e16b>:43: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   publishers=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[5]")
# <ipython-input-8-360a4e56e16b>:53: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   genres=driver.find_elements_by_xpath("//table[@class='in-article sortable']/tbody/tr/td[6]")
#                                             Book_name       Author_name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# 0    5,094,805       Transworld  Crime, Thriller & Adventure
# 1    4,475,152       Bloomsbury           Children's Fiction
# 2    4,200,654       Bloomsbury           Children's Fiction
# 3    4,179,479       Bloomsbury           Children's Fiction
# 4    3,758,936     Random House              Romance & Sagas
# ..         ...              ...                          ...
# 95     807,311     Random House   General & Literary Fiction
# 96     794,201          Penguin        Food & Drink: General
# 97     792,187  Scholastic Ltd.          Young Adult Fiction
# 98     791,507            Orion           Biography: General
# 99     791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# Q9.Scrape the details most watched tv series of all time from imdb.com. Url = https://www.imdb.com/list/ls095964455/ You have to find the following details: A) Name B) Year span C) Genre D) Run time E) Ratings F) Votes

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)

url = "https://www.imdb.com/list/ls095964455"
driver.get(url)
time.sleep(2)


name=[]
try:
    names=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
    for i in names:
        name.append(i.text)
except NosuchElementException:
    name.append('No details available')
time.sleep(2)


years=[]
try:
    span=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/span[2]")
    for i in span:
        years.append(i.text)
except NosuchElementException:
    years.append('No details available')
time.sleep(2)



genre=[]
try:
    genres=driver.find_elements_by_xpath("//span[@class='genre']")
    for i in genres:
        genre.append(i.text)
except NoSuchElementException:
    genre.append('No details available')
time.sleep(2)



run_time=[]
try:
    info=driver.find_elements_by_xpath("//span[@class='runtime']")
    for i in info:
        run_time.append(i.text)
except NoSuchElementException:
    run_time.append('No details available')
time.sleep(2)



rating=[]
try:
    info=driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']/span[2]")
    for i in info:
        rating.append(i.text)
except NoSuchElementException:
    rating.append('No details available')
time.sleep(2)


votes=[]
try:
    info=driver.find_elements_by_xpath("//span[@name='nv']")
    for i in info:
        votes.append(i.text)
except NoSuchElementException:#handling no such element exception
    votes.append('No details available')
time.sleep(2)



df=pd.DataFrame({"Name":name,
                "years":years,
                "Genre":genre,
                "Run_time":run_time,
                "Rating":rating,
                "Votes":votes})
df
# Out:
# <ipython-input-9-fc3d5a98765b>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("chromedriver.exe")
# <ipython-input-9-fc3d5a98765b>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   names=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a")
# <ipython-input-9-fc3d5a98765b>:23: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   span=driver.find_elements_by_xpath("//h3[@class='lister-item-header']/span[2]")
# <ipython-input-9-fc3d5a98765b>:34: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   genres=driver.find_elements_by_xpath("//span[@class='genre']")
# <ipython-input-9-fc3d5a98765b>:45: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   info=driver.find_elements_by_xpath("//span[@class='runtime']")
# <ipython-input-9-fc3d5a98765b>:56: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   info=driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']/span[2]")
# <ipython-input-9-fc3d5a98765b>:66: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   info=driver.find_elements_by_xpath("//span[@name='nv']")
#                               Name        years                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run_time Rating      Votes
# 0    57 min    9.2  1,894,523
# 1    51 min    8.7    925,824
# 2    44 min    8.2    910,220
# 3    60 min    7.5    272,384
# 4    43 min    7.6    232,770
# ..      ...    ...        ...
# 95   42 min    7.5     46,259
# 96   50 min    7.8     57,098
# 97   42 min    8.1    179,242
# 98   45 min    7.1     37,536
# 99  572 min    8.6    210,643
#
# [100 rows x 6 columns]

# %% [markdown]
# Q10. Details of Datasets from UCI machine learning repositories. Url = https://archive.ics.uci.edu/ You have to find the following details: A) Dataset name B) Data type C) Task D) Attribute type E) No of instances F) No of attribute G) Year Note: - from

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)


url = "https://archive.ics.uci.edu/"
driver.get(url)
time.sleep(2)


show=driver.find_element_by_xpath("//a[@href='datasets.php']")
show.click()
time.sleep(1)



name=[]
try:
    names=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
    for i in names:
        name.append(i.text)
except NoSuchElementException:
    name.append('No details available')
time.sleep(2)


data_type=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
    for i in info[1:]:
         data_type.append(i.text)
except NoSuchElementException:
    data_type.append("No information")
time.sleep(2)



default_task=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]")
    for i in info[1:]:
         default_task.append(i.text)
except NoSuchElementException:
    default_task.append("No information")
time.sleep(2)



attr_type=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]")
    for i in info[1:]:
         attr_type.append(i.text)
except NoSuchElementException:
    attr_type.append("No information")
time.sleep(2)



no_of_instances=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]")
    for i in info[1:]:
         no_of_instances.append(i.text)
except NoSuchElementException:
    no_of_instances.append("No information")
time.sleep(2)



no_of_attributes=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]")
    for i in info[1:]:
         no_of_attributes.append(i.text)
except NoSuchElementException:
    no_of_attributes.append("No information")
time.sleep(2)



year=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]")
    for i in info[1:]:
         year.append(i.text)
except NoSuchElementException:
    year.append("No information")
time.sleep(2)


df=pd.DataFrame({'Name':name,
                'Data_type':data_type,
                'Task':default_task,
                'Attribute_type':attr_type,
                'No_of_instances':no_of_instances,
                'No_of_attributes':no_of_attributes,
                'Year':year})
df
# Out:
# <ipython-input-10-d60f0c1c086d>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("chromedriver.exe")
# <ipython-input-10-d60f0c1c086d>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   show=driver.find_element_by_xpath("//a[@href='datasets.php']")
# <ipython-input-10-d60f0c1c086d>:18: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   names=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
# <ipython-input-10-d60f0c1c086d>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
# <ipython-input-10-d60f0c1c086d>:39: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]")
# <ipython-input-10-d60f0c1c086d>:50: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]")
# <ipython-input-10-d60f0c1c086d>:61: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]")
# <ipython-input-10-d60f0c1c086d>:72: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]")
# <ipython-input-10-d60f0c1c086d>:83: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]")
#                                  Name      Data_type                  Task  \
# 0                             Abalone  Multivariate        Classification
# 1                               Adult  Multivariate        Classification
# 2                           Annealing  Multivariate        Classification
# 3        Anonymous Microsoft Web Data                 Recommender-Systems
# 4                          Arrhythmia  Multivariate        Classification
# ..                                ...            ...                   ...
# 583  in-vehicle coupon recommendation  Multivariate        Classification
# 584               Gait Classification  Multivariate        Classification
# 585         Wikipedia Math Essentials   Time-Series            Regression
# 586         Wikipedia Math Essentials   Time-Series            Regression
# 587      Synchronous Machine Data Set  Multivariate            Regression
#
#                   Attribute_type No_of_instances No_of_attributes   Year
# 0    Categorical, Integer, Real            4177                8   1995
# 1          Categorical, Integer           48842               14   1996
# 2    Categorical, Integer, Real             798               38
# 3                   Categorical           37711              294   1998
# 4    Categorical, Integer, Real             452              279   1998
# ..                           ...             ...              ...    ...
# 583                                       12684               23   2020
# 584                        Real              48              321   2020
# 585                        Real             731             1068   2021
# 586                        Real             731             1068   2021
# 587                        Real             557                5   2021
#
# [588 rows x 7 columns]
